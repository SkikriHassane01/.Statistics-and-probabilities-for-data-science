# %% [markdown]
# <a href="https://www.kaggle.com/code/hassaneskikri/01-statistical-analysis-step-by-step?scriptVersionId=193182078" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style ="font-family:Trebuchet MS; background-color : #f8f0fa; border-left: 5px solid #1b4332; padding: 6px; border-radius: 50px 50px;">
#     <h2 style="color: #1b4332; font-size: 48px; text-align: center;">
#         <b>01. Statistical analysis step by step</b>
#         <hr style="border-top: 2px solid #264653;">
#     </h2>
#     <h3 style="font-size: 14px; color: #264653; text-align: left;padding:15px ;"><strong> I hope this is very helpful. let's started .</strong></h3>
# </div>

# %% [markdown]
# <h1 style="background-color: #12f7ff;
#            font-family: 'Trebuchet MS', sans-serif;
#            color: #000;
#            font-size: 150%;
#            text-align: center;
#            border-radius: 50px 50px;
#            padding: 20px 20px ;
#            margin: 30px 30px;
#            box-shadow: 0 0 10px rgba(18,247,255,0.6),
#     0 0 20px rgba(18,247,255,0.6),
#     0 0 30px rgba(18,247,255,0.6),
#     0 0 40px rgba(18,247,255,0.6);"> Introduction </h1>

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Cambria', sans-serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 18px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
# <h2>What Statistical analysis mean ?</h2>
# Statistical analysis means investigating trends, patterns, and relationships using quantitative data. It is an important research tool used by scientists, governments, businesses, and other organizations to draw valid conclusions. Statistical analysis requires careful planning from the very start of the research process. You need to specify your hypotheses and make decisions about your research design, sample size, and sampling procedure.
#
# After collecting data from your sample, you can organize and summarize the data using descriptive statistics. Then, you can use inferential statistics to formally test hypotheses and make estimates about the population. Finally, you can interpret and generalize your findings.
# <h3>alonge this article we will practice an example to undersand each topic very will so our example is:</h3>
# Investigating the potential effect of a study technique (e.g., using score_flashcardss, roadmaps) on <strong>the scores of a final exam in a college course.</strong> Our aim is to see if the technique improves scores or not.
# </div>

# %%
# importing the liberaries
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# to ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# simulate data 
np.random.seed(42)  # To Ensure reproducibility

### Q: Why adding the seed(42) to the random?

### The key idea is to pick any number as a seed to ensure that the random number generation is deterministic,meaning that anyone using the same seed with the same code will get the same result

scores_flashcards = np.random.normal(loc=75, scale=10, size=15)  # (loc:average, scale: standard deviation)
scores_traditional = np.random.normal(loc=70, scale=10, size=15)

# Create the DataFrame
df = pd.DataFrame({
    'score_flashcards': scores_flashcards,
    'score_traditional': scores_traditional
})

print(f"the DataFrame with {df.shape[0]} columns and {df.shape[1]} rows.")
df.head()
# Out:
# the DataFrame with 15 columns and 2 rows.
#    score_flashcards  score_traditional
# 0         79.967142          64.377125
# 1         73.617357          59.871689
# 2         81.476885          73.142473
# 3         90.230299          60.919759
# 4         72.658466          55.876963

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Cambria', sans-serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 18px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
# <h1> Step1: Write you hypotheses</h1>
# The goal of research is often to investigate a relationship between variables within a population. You start with a prediction, and use statistical analysis to test that prediction.
#
# A statistical hypothesis is a formal way of writing a prediction about a population. Every research prediction is rephrased into null and alternative hypotheses that can be tested using sample data.
#
# While the null hypothesis always predicts no effect or no relationship between variables, the alternative hypothesis states your research prediction of an effect or relationship.
# <h3>In our example:</h3>
# <ul>
# <li>Null hypothesis (H0): The flashcard study technique has no effect on final exam scores.</li>
# <li>Alternative hypothesis (H1): The flashcard study technique improves final exam scores.</li>
# </ul>
# <h1>Step2: Planning your research design</h1>
#
# A research design is your overall strategy for data collection and analysis. It determines the statistical tests you can use to test your hypothesis later on.
#
# First, decide whether your research will use a descriptive, correlational, or experimental design. Experiments directly influence variables, whereas descriptive and correlational studies only measure variables.
# <ul>
# <li> In an experimental design, you can assess a cause-and-effect relationship using statistical tests of comparison or regression.</li>
# <li> In a correlational design, you can explore relationships between variables  without any assumption of causality using correlation coefficients and significance tests.</li>
# <li> In a descriptive design, you can study the characteristics of a population or phenomenon using statistical tests to draw inferences from sample data.</li>
# </ul>
# <h3> In the example</h3>
#
# We'll use an experimental design, dividing participants into two groups: one using the flashcard technique (treatment group) and the other using traditional study methods (control group).
#
# <h1> Step 3: Measuring variables</h1>
# When planning a research design, you should operationalize your variables and decide exactly how you will measure them.
#
# For statistical analysis, it’s important to consider the level of measurement of your variables, which tells you what kind of data they contain:
# <ul>
# <li> Categorical data represents groupings. These may be nominal (e.g., gender) or ordinal (e.g. level of language ability).</li>
# <li> Quantitative data represents amounts. These may be on an interval scale (e.g. test score) or a ratio scale (e.g. age).</li>
# </ul>
# <h3>In our example </h3>
#
# <li> Independent variable: Study technique (flashcards vs. traditional)</li>
# <li> Dependent variable: Final exam score (quantitative data)</li>
#
# <h1>Step 4: Collect data from a sample</h1>
# In most cases, it’s too difficult or expensive to collect data from every member of the population you’re interested in studying. Instead, you’ll collect data from a sample.
#
# Statistical analysis allows you to apply your findings beyond your own sample as long as you use appropriate sampling procedures. You should aim for a sample that is representative of the population.
#
# <h2>a. Sampling for statistical analysis</h2>
#
# There are two main approaches to selecting a sample.
#
# - **Probability sampling:** every member of the population has a chance of being selected for the study through random selection.
# - **Non-probability sampling:** some members of the population are more likely than others to be selected for the study because of criteria such as convenience or voluntary self-selection.
#
# Probability sampling is preferred for its ability to minimize bias and support stronger statistical inferences through parametric tests. However, due to practical challenges, non-probability samples are often used, necessitating non-parametric tests which provide weaker inferences. Researchers using parametric tests with non-probability samples must demonstrate their sample's representativeness and lack of systematic bias.
#
# ## b. Calculate sufficient sample size
#
# Before recruiting participants, decide on your sample size either by looking at other studies in your field or using statistics. A sample that’s too small may be unrepresentative of the sample, while a sample that’s too large will be more costly than necessary.
#
# There are many [sample size calculators online](https://www.ai-therapy.com/psychology-statistics/sample-size-calculator).
#
# To use these calculators, you have to understand and input these key components:
#
# - Significance level (alpha): the risk of rejecting a true null hypothesis that you are willing to take, usually set at 5%.
# - Statistical power: the probability of your study detecting an effect of a certain size if there is one, usually 80% or higher.
# - Expected effect size: a standardized indication of how large the expected result of your study will be, usually based on other similar studies.
# - Population standard deviation: an estimate of the population parameter based on a previous study or a pilot study of your own.
#
# ### In our example
# Suppose we conduct a probability sampling and end up with 30 students, 15 using flashcards and 15 using traditional methods.
# # Step 5: Summarize your data with descriptive statistics
#
# Once you’ve collected all of your data, you can inspect them and calculate descriptive statistics that summarize them.
#
# ## a. Inspect your data
#
# There are various ways to inspect your data, including the following:
#
# - Organizing data from each variable in frequency distribution tables.
# - Displaying data from a key variable in a bar chart to view the distribution of responses.
# - Visualizing the relationship between two variables using a scatter plot.
# By visualizing your data in tables and graphs, you can assess whether your data follow a skewed or normal distribution and whether there are any outliers or missing data.
#
# ## b.Calculate measures of central tendency
# Measures of central tendency describe where most of the values in a data set lie. Three main measures of central tendency are often reported:
#
# - **Mode:** the most popular response or value in the data set.
# - **Median:** the value in the exact middle of the data set when ordered from low to high.
# - **Mean:** the sum of all values divided by the number of values.
#
# However, depending on the shape of the distribution and level of measurement, only one or two of these measures may be appropriate. For example, many demographic characteristics can only be described using the mode or proportions, while a variable like reaction time may not have a mode at all.
#
# ## c. Calculate measures of variability
# Measures of variability tell you how spread out the values in a data set are. Four main measures of variability are often reported:
#
# - **Range:** the highest value minus the lowest value of the data set.
# - **Interquartile range:** the range of the middle half of the data set.
# - **Standard deviation:** the average distance between each value in your data set and the mean.
# - **Variance:** the square of the standard deviation.
#
# Once again, the shape of the distribution and level of measurement should guide your choice of variability statistics. The interquartile range is the best measure for skewed distributions, while standard deviation and variance provide the best information for normal distributions.
# </div>

# %%
Count_score_flashcardss = df['score_flashcards'].value_counts().sum()
Count_traditional = df['score_traditional'].value_counts().sum()


print(f"There is {Count_score_flashcardss} students using score_flashcardss and {Count_traditional} students using traditional methods")
print(f"The total is :{Count_score_flashcardss + Count_traditional} Students")
# Out:
# There is 15 students using score_flashcardss and 15 students using traditional methods
# The total is :30 Students

# %%
central_tendency = {
    "Measure": ["Mode", "Median", "Mean"],
    "score_flashcards": [df["score_flashcards"].mode()[0], df["score_flashcards"].median(), df["score_flashcards"].mean()],
    "score_traditional": [df["score_traditional"].mode()[0], df["score_traditional"].median(), df["score_traditional"].mean()]
}

variability = {
    "Measure": ["Range", "IQR", "Standard Deviation", "Variance"],
    "score_flashcards": [
        df["score_flashcards"].max() - df["score_flashcards"].min(),
        df["score_flashcards"].quantile(0.75) - df["score_flashcards"].quantile(0.25),
        df["score_flashcards"].std(),
        df["score_flashcards"].var()
    ],
    "score_traditional": [
        df["score_traditional"].max() - df["score_traditional"].min(),
        df["score_traditional"].quantile(0.75) - df["score_traditional"].quantile(0.25),
        df["score_traditional"].std(),
        df["score_traditional"].var()
    ]
}

# Convert the dictionaries to DataFrames
central_tendency_df = pd.DataFrame(central_tendency)
variability_df = pd.DataFrame(variability)

# Display the statistics
print("Descriptive Statistics:")

print("\nMeasures of Central Tendency:\n")
central_tendency_df
# Out:
# Descriptive Statistics:
#
# Measures of Central Tendency:
#   Measure  score_flashcards  score_traditional
# 0    Mode         55.867198          55.752518
# 1  Median         73.617357          64.556173
# 2    Mean         75.103485          66.133577

# %%
print("\nMeasures of Variability:\n")
variability_df
# Out:
# Measures of Variability:
#               Measure  score_flashcards  score_traditional
# 0               Range         34.924931          28.903970
# 1                 IQR         10.596980          10.496530
# 2  Standard Deviation          9.941558           7.778856
# 3            Variance         98.834567          60.510594

# %%
# or there is a simple way to do this using df.describe() function:

# First Calculate descriptive statistics
desc_stats = df.describe().transpose()

# Adding mode separately as it's not included in describe 
desc_stats['Mode'] = [df['score_flashcards'].mode()[0], df['score_traditional'].mode()[0]]
# you can add any other mesurment here 

# Display the descriptive statistics
print("Descriptive Statistics:\n")
desc_stats
# Out:
# Descriptive Statistics:
#                    count       mean       std        min        25%  \
# score_flashcards    15.0  75.103485  9.941558  55.867198  70.354263
# score_traditional   15.0  66.133577  7.778856  55.752518  60.395724
#
#                          50%        75%        max       Mode
# score_flashcards   73.617357  80.951243  90.792128  55.867198
# score_traditional  64.556173  70.892254  84.656488  55.752518

# %%
# display a histplot for the two columns

plt.figure(figsize=(16,6))
plt.suptitle("histplot for the two columns")
plt.subplot(1,2,1)
sns.histplot(df['score_flashcards'],kde = True,bins =10)
plt.title("score_flashcardss group")
plt.subplot(1,2,2)
sns.histplot(df['score_traditional'],kde = True,bins =10)
plt.title("traditional group")
plt.tight_layout()
plt.show()

# %%
plt.scatter(df['score_flashcards'], df['score_traditional'])
plt.title('score_flashcardss vs Traditional Scores')
plt.xlabel('score_flashcardss Scores')
plt.ylabel('Traditional Scores')
plt.show()

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Cambria', sans-serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 18px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#      <h1> Step6: Test hypotheses or make estimates with inferential statistics</h1>
#     A number that describes a sample is called a statistic, while a number describing a population is called a parameter. Using inferential statistics, you can make conclusions about population parameters based on sample statistics.
#
# Researchers often use two main methods (simultaneously) to make inferences in statistics.
#
# - **Estimation:** calculating population parameters based on sample statistics.
# - **Hypothesis testing:** a formal process for testing research predictions about the population using samples.
#
# ## a.Estimation
#
# You can make two types of estimates of population parameters from sample statistics:
#
# - **A point estimate:** a value that represents your best guess of the exact parameter.
# - **An interval estimate:** a range of values that represent your best guess of where the parameter lies.
#
#
#
# ## b.Hypothesis testing
#
# Using data from a sample, you can test hypotheses about relationships between variables in the population. Hypothesis testing starts with the assumption that the null hypothesis is true in the population, and you use statistical tests to assess whether the null hypothesis can be rejected or not.
#
# Statistical tests determine where your sample data would lie on an expected distribution of sample data if the null hypothesis were true. These tests give two main outputs:
#
# - A **test statistic** tells you how much your data differs from the null hypothesis of the test.
# - A **p value** tells you the likelihood of obtaining your results if the null hypothesis is actually true in the population.
#
# Statistical tests come in three main varieties:
#
# - Comparison tests assess group differences in outcomes.
# - Regression tests assess cause-and-effect relationships between variables.
# - Correlation tests assess relationships between variables without assuming causation.
#
# Your choice of statistical test depends on your research questions, research design, sampling method, and data characteristics.
#
# ## c. Parametric tests
#
# Parametric tests make powerful inferences about the population based on sample data. But to use them, some assumptions must be met, and only some types of variables can be used. If your data violate these assumptions, you can perform appropriate data transformations or use alternative non-parametric tests instead.
#
# A regression models the extent to which changes in a predictor variable results in changes in outcome variable(s).
#
# - A simple linear regression includes one predictor variable and one outcome variable.
# - A multiple linear regression includes two or more predictor variables and one outcome variable.
#
# Comparison tests usually compare the means of groups. These may be the means of different groups within a sample (e.g., a treatment and control group), the means of one sample group taken at different times (e.g., pretest and posttest scores), or a sample mean and a population mean.
#
# - A t test is for exactly 1 or 2 groups when the sample is small (30 or less).
# - A z test is for exactly 1 or 2 groups when the sample is large.
# - An ANOVA is for 3 or more groups.
#
#
# ## d. correlation
#
# The only parametric correlation test is Pearson’s r. The correlation coefficient (r) tells you the strength of a linear relationship between two quantitative variables.
#
# However, to test whether the correlation in the sample is strong enough to be important in the population, you also need to perform a significance test of the correlation coefficient, usually a t test, to obtain a p value. This test uses your sample size to calculate how much the correlation coefficient differs from zero in the population.
# ### In our example:
# We'll use a t-test to compare the two groups since we're comparing the means of two independent groups.
# </div>

# %%
t_stat, p_value = stats.ttest_ind(scores_flashcards, scores_traditional)

print("\nHypothesis Testing Results:")
print(f"T-statistic: {t_stat:.2f}")
print(f"P-value: {p_value:.4f}")
# Out:
# Hypothesis Testing Results:
# T-statistic: 2.75
# P-value: 0.0103

# %%
correlation, p_value_corr = stats.pearsonr(scores_flashcards, scores_traditional)
print(correlation, p_value_corr)

# or we can to use .corr()
correlation_matrix = df.corr()
print(f"\n {correlation_matrix}\n")

plt.figure(figsize=(16,8))
sns.heatmap(correlation_matrix,annot=True,cmap="coolwarm",center=0)
plt.title('Correlation between score_flashcardss and Traditional Scores')
plt.show()
# Out:
# 0.09472535125379335 0.7370228839110046
#
#                     score_flashcards  score_traditional
# score_flashcards           1.000000           0.094725
# score_traditional          0.094725           1.000000

# %% [markdown]
# <div style="background-color: #fcf8e8; /* Notepad yellow */
#            font-family: 'Cambria', sans-serif; /* Classic font for note-taking */
#            color: #000;
#            font-size: 18px; /* Standard text size */
#            line-height: 1.5; /* Spacing between lines of text */
#            text-align: left;
#            border-radius: 5px;
#            padding: 20px;
#            margin: 20px;
#            width: 90%;
#            box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2); /* Realistic shadow */
#            background-image: linear-gradient(rgba(0, 0, 0, 0.1) 1px, transparent 1px),
#                              linear-gradient(to right, rgba(0, 0, 0, 0.1) 1px, transparent 1px);
#            background-size: 100% 30px, 30px 100%; /* Size of the lines */
#            border: 1px solid #ddd; /* Border for paper edge */
#            ">
#
# # Step 7: Interpret your results
#
# The final step of statistical analysis is interpreting your results.
#
# ## a. Statistical significance
#
# In hypothesis testing, statistical significance is the main criterion for forming conclusions. You compare your p value to a set significance level (usually 0.05) to decide whether your results are statistically significant or non-significant.
#
# ## b. Effect size
#
# A statistically significant result doesn’t necessarily mean that there are important real life applications or clinical outcomes for a finding.
#
# In contrast, the effect size indicates the practical significance of your results. It’s important to report effect sizes along with your inferential statistics for a complete picture of your results.
#
# ## c. Frequentist versus Bayesian statistics
#
# Traditionally, frequentist statistics emphasizes null hypothesis significance testing and always starts with the assumption of a true null hypothesis.
#
# However, Bayesian statistics has grown in popularity as an alternative approach in the last few decades. In this approach, you use previous research to continually update your hypotheses based on your expectations and observations.
#
# Bayes factor compares the relative strength of evidence for the null versus the alternative hypothesis rather than making a conclusion about rejecting the null hypothesis or not.
# </div>

# %%
# Interpret Results
alpha = 0.05
if p_value < alpha:
    print("\nReject the null hypothesis - suggest the score_flashcards technique improves exam scores.")
else:
    print("\nFail to reject the null hypothesis - no significant improvement was observed.")

# Effect size (Cohen's d)
cohen_d = (scores_flashcards.mean() - scores_traditional.mean()) / (np.sqrt((scores_flashcards.std()**2 + scores_traditional.std()**2) / 2))
print(f"Effect Size (Cohen's d): {cohen_d:.2f}")
# Out:
# Reject the null hypothesis - suggest the score_flashcards technique improves exam scores.
# Effect Size (Cohen's d): 1.04

# %% [markdown]
# Cohen's d values are typically interpreted as follows:
#
# - Small effect size: d = 0.2
# - Medium effect size: d = 0.5
# - Large effect size: d = 0.8

# %% [markdown]
# ## **resources:**
#
# - [The main article](https://www.scribbr.com/category/statistics/)
